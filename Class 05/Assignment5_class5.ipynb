# %% [markdown]
# #Introduction to Python Programming
# [https://www.isical.ac.in/~prasantadutta/intro2py](https://www.isical.ac.in/~prasantadutta/intro2py)
#
# ## Assignment 5

# %% [markdown]
# 1. Implement ternary operator using Python *tuple*
# 2. Implement ternary operator using Python *dictionary*

# %%
a, b = 10, 20
min_value = (b, a)[a < b]
min_value
# Out:
# 10

# %%
a, b = 10, 20
min_value = {True: a, False: b}[a < b]
min_value
# Out:
# 10
